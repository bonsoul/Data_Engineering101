# %%
import pandas as pd
import os

# %%
input_path = r'D:\Documents\Data Engineering\Data_Engineering101\data-engineering-essentials\035 Python Essentials for Data Engineers\05 Project 1 - File Format Converter\data\retail_db\1FINAL CHOLERA LINELIST 2022_2024_Bonsoul.xlsx'
output_path = os.path.splitext(input_path)[0] + '.json'

# %%
df = pd.read_excel(input_path)
df.to_json(output_path, orient='records', indent=4)

# %%
from sqlalchemy import create_engine

# %%
#database

username = 'itversity_retail_user1'
password = 'itversity'
host = 'localhost'
port = '5432'
database  = 'itversity_retail_db'

# %%
#engine


engine = create_engine('postgresql+psycopg2://itversity_retail_user1:itversity@localhost:5432/itversity_retail_db')

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("GRANT ALL PRIVILEGES ON SCHEMA public TO itversity_retail_user1;"))

# %%
df.to_sql('cholera_linelists', engine, if_exists='replace', index=False)
# Out:
# 666

# %%
from sqlalchemy import create_engine
import pandas as pd

# Read table
df_read = pd.read_sql_table('cholera_linelists', con=engine)

# %%
df_read.head(10)
# Out:
#    id_no conducted_ocv_campaign in the subcounty campaign_start_date  \
# 0      1                                      No                 NaT
# 1      2                                      No                 NaT
# 2      3                                     Yes          2023-08-02
# 3      4                                      No                 NaT
# 4      5                                      No                 NaT
# 5      6                                      No                 NaT
# 6      7                                      No                 NaT
# 7      8                                      No                 NaT
# 8      9                                      No                 NaT
# 9     10                                      No                 NaT
#
#   campaign_end_date type_of_ocv_usedeuvichol/shancol hospitalization status  \
# 0               NaT                             None                    Yes
# ...

# %%
df_read.columns
# Out:
# Index(['id_no', 'conducted_ocv_campaign in the subcounty',
#        'campaign_start_date', 'campaign_end_date',
#        'type_of_ocv_usedeuvichol/shancol', 'hospitalization status', 'county',
#        'sub_county', 'village/town_and_neighborhood', 'ward',
#        'name_of_health_facility', 'sex', 'age',
#        'date_seen_at_health_facility.1', 'date_of_onset_of_diseases.1',
#        'epi_week', 'number_of_doses_of_vaccines', 'rdt_yes_no', 'rdt_results',
#        'culture_yes_no', 'culture_results', 'sero_type', 'age_analysis',
#        'place_of_death', 'outcome', 'vaccination_status'],
#       dtype='object')

# %%
df_read.isnull().sum()
# Out:
# id_no                                          0
# conducted_ocv_campaign in the subcounty        0
# campaign_start_date                         4582
# campaign_end_date                           4582
# type_of_ocv_usedeuvichol/shancol            4582
# hospitalization status                         0
# county                                         0
# sub_county                                     0
# village/town_and_neighborhood                411
# ward                                         623
# name_of_health_facility                      102
# sex                                            0
# age                                          107
# date_seen_at_health_facility.1               655
# date_of_onset_of_diseases.1                    0
# epi_week                                       0
# number_of_doses_of_vaccines                    0
# rdt_yes_no                                     0
# rdt_results                                 9495
# ...
